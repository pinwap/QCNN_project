# %%
# !git clone https://github.com/pinwap/QCNN_project.git
# %cd QCNN_project
# Out:
# Cloning into 'QCNN_project'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 86 (delta 48), reused 70 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 111.55 KiB | 12.39 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/QCNN_project/QCNN_project

# %%
# !uv sync
# Out:
# Using CPython 3.13.11
# Creating virtual environment at: .venv
# Resolved 60 packages in 6ms
# Prepared 59 packages in 1m 42s
# Installed 59 packages in 623ms
#  + cfgv==3.5.0
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + dill==0.4.1
#  + distlib==0.4.0
#  + filelock==3.20.3
#  + fonttools==4.61.1
#  + fsspec==2026.1.0
#  + identify==2.6.16
#  + jinja2==3.1.6
#  + joblib==1.5.3
#  + kiwisolver==1.4.9
#  + markupsafe==3.0.3
#  + matplotlib==3.10.8
#  + mpmath==1.3.0
#  + networkx==3.6.1
#  + nodeenv==1.10.0
#  + numpy==2.4.1
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
#  + nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufile-cu12==1.13.1.3
#  + nvidia-curand-cu12==10.3.9.90
#  + nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparselt-cu12==0.7.1
#  + nvidia-nccl-cu12==2.27.5
#  + nvidia-nvjitlink-cu12==12.8.93
# ...

# %%
# !uv run main.py
# Out:
# Traceback (most recent call last):
#   File "/content/QCNN_project/QCNN_project/main.py", line 5, in <module>
#     import matplotlib.pyplot as plt
#   File "/content/QCNN_project/QCNN_project/.venv/lib/python3.13/site-packages/matplotlib/__init__.py", line 1299, in <module>
#     rcParams['backend'] = os.environ.get('MPLBACKEND')
#     ~~~~~~~~^^^^^^^^^^^
#   File "/content/QCNN_project/QCNN_project/.venv/lib/python3.13/site-packages/matplotlib/__init__.py", line 774, in __setitem__
#     raise ValueError(f"Key {key}: {ve}") from None
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']
