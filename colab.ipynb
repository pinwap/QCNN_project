# %%
import os

from google.colab import drive

# เชื่อมต่อ Google Drive
print("🔗 Mounting Google Drive...")
drive.mount("/content/drive")

# สร้างโฟลเดอร์สำหรับเก็บผลลัพธ์ (ถ้ายังไม่มี)
# แนะนำให้ตั้งชื่อโฟลเดอร์ชัดเจน เช่น QCNN_Results
save_path = "/content/drive/My Drive/QCNN_Results"
os.makedirs(save_path, exist_ok=True)
print(f"📂 Save path set to: {save_path}")

# %%
# !git clone https://github.com/pinwap/QCNN_project.git
# %cd QCNN_project

# %%
# !uv sync

# %%
# !uv run main.py
